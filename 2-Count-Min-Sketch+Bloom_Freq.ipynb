# %%
import bs4
import requests
import json
import time
import os
import pandas as pd
import numpy as np
from random import shuffle
from thefuzz import process, fuzz
from modules.CountMinSketch.count_min_sketch2 import CountMinSketch2
from modules.BloomFilter.bloom_filter2 import BloomFilter2
from modules.Dataset.dataset import Dataset

# %%
def format_word(word):
  if len(word) > 1:
    last_char = word[-1]
    while not last_char.isalpha():
      word = word[:-1]
      last_char = word[-1]

    first_char = word[0]
    while not first_char.isalpha():
      word = word[1:]
      first_char = word[0]

    word = word.lower()

  return word

# %%
words_set = []
for i in range(10):
  candidates_file = f"./dataset/dataset_candidates_{i}.txt"
  with open(candidates_file, 'r') as f:
    words_list = f.read().split('\n')
    words_set.append({"words_list": words_list})

# %%
NUM_COUNTERS = 300000
NUM_HASH_FUNCTIONS = 100

for index, words_list in enumerate(words_set):
    print(f"Init CMS - {index + 1} of {len(words_set)}")
    cms = CountMinSketch2(buckets=NUM_COUNTERS, tables=NUM_HASH_FUNCTIONS)
    for word in words_list["words_list"]:
        cms.increment(word)
    words_set[index]['words_cms'] = cms
    del cms
# Out:
# Init CMS - 1 of 10
# Init CMS - 2 of 10
# Init CMS - 3 of 10
# Init CMS - 4 of 10
# Init CMS - 5 of 10
# Init CMS - 6 of 10
# Init CMS - 7 of 10
# Init CMS - 8 of 10
# Init CMS - 9 of 10
# Init CMS - 10 of 10

# %%
p = 0.01 #false positive probability 

for index, words_list in enumerate(words_set):
    print(f"Init BLOOM - {index + 1} of {len(words_set)}")
    n = len(words_list["words_list"]) #no of items to add
    bloomf = BloomFilter2(n,p)
    for word in words_list["words_list"]:
        bloomf.add(word)
    words_set[index]['words_bloomf'] = bloomf
    del bloomf
# Out:
# Init BLOOM - 1 of 10
# Init BLOOM - 2 of 10
# Init BLOOM - 3 of 10
# Init BLOOM - 4 of 10
# Init BLOOM - 5 of 10
# Init BLOOM - 6 of 10
# Init BLOOM - 7 of 10
# Init BLOOM - 8 of 10
# Init BLOOM - 9 of 10
# Init BLOOM - 10 of 10

# %%
#some_word_with_error = "appel"
some_sentance_with_error = "I wanna appel pleases or a bannana with a paer and a lemone, or a wartermelon if possibe. I hope i don't have an errof"
correct_sentence = "I wanna apple please or a banana with a pear and a lemon, or a watermelon if possible. I hope i don't have an error"
diff_words_to_correct = list(set([format_word(x) for x in correct_sentence.split()]) - set([format_word(x) for x in some_sentance_with_error.split()]))
new_sentance = []
words_set_out = []

for index, words_list in enumerate(words_set):
    time_start_naive = time.time()
    words_set_out.append({})
    words_set_out[index]["matched_words"] = []
    words_set_out[index]["matched_scores"] = []
    words_set_out[index]["words_frequency"] = []
    start = time.time()
    for word in some_sentance_with_error.split():
        word = format_word(word)
        if not word in words_list["words_bloomf"]:
            success_percentage = max((len(word) - 1) / len(word) * 100, 75)
            print(f"Scanning {word}, success_percentage is {success_percentage}")
            print("==========================")
            word_results = [(format_word(x[0]), x[1]) for x in process.extract(word, words_list["words_list"], scorer=fuzz.ratio)]# if x[1] >= success_percentage]
            word_results = list(set(word_results))
            if (len(word_results) > 0 and word_results[0][1] < 100):
                list_fixes = list([x[0] for x in word_results])
                list_scores = list([x[1] for x in word_results])
                list_freq = list([words_list["words_cms"].count(x[0]) for x in word_results])
                for idx, fix in enumerate(list_fixes):
                    print(f"Potential fix of {word} is {fix}")
                    print(f"Frequency is {list_freq[idx]}")
                    print(f"Match rate is {list_scores[idx]}")
                    print("==========================")
                words_set_out[index]["matched_words"].append(set(list_fixes) if len(list_fixes) > 1 else list_fixes[0])
                words_set_out[index]["matched_scores"].append(set(list_scores) if len(list_scores) > 1 else list_scores[0])
                words_set_out[index]["words_frequency"].append(set(list_freq) if len(list_freq) > 1 else list_freq[0])
            else:
                words_set_out[index]["matched_words"].append(None)
                words_set_out[index]["matched_scores"].append(None)
                words_set_out[index]["words_frequency"].append(None)
                continue
        else:
            print(f"Word {word} is correct. Skipping")
            words_set_out[index]["matched_words"].append(None)
            words_set_out[index]["matched_scores"].append(None)
            words_set_out[index]["words_frequency"].append(None)
    
    end = time.time()
    print(f"Total runtime of {(end - start)} seconds")
    words_set_out[index]["time_sec"] = (end - start)
# Out:
# Word I is correct. Skipping
# Word wanna is correct. Skipping
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 9.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is bangunan
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of bannana is bananas
# Frequency is 1.0
# Match rate is 86
# ==========================
# Potential fix of bannana is bandanna
# Frequency is 2.0
# Match rate is 80
# ==========================
# Potential fix of bannana is lannan
# Frequency is 0.0
# Match rate is 77
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 15.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 29.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errors
# Frequency is 3.0
# Match rate is 73
# ==========================
# Potential fix of errof is rirwof
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is rnrhof
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is error
# Frequency is 1.0
# Match rate is 80
# ==========================
# Total runtime of 0.3886857032775879 seconds
# Word I is correct. Skipping
# Word wanna is correct. Skipping
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 13.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is leases
# Frequency is 2.0
# Match rate is 92
# ==========================
# Potential fix of pleases is please
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is banana
# Frequency is 1.0
# Match rate is 92
# ==========================
# Potential fix of bannana is hannan
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is ananta
# Frequency is 0.0
# Match rate is 77
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 12.0
# Match rate is 89
# ==========================
# Potential fix of paer is pater
# Frequency is 1.0
# Match rate is 89
# ==========================
# Potential fix of paer is pager
# Frequency is 1.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is leon
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of lemone is lemmon
# Frequency is 0.0
# Match rate is 83
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 28.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is error
# Frequency is 2.0
# Match rate is 80
# ==========================
# Total runtime of 0.3686199188232422 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 7.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is banana
# Frequency is 1.0
# Match rate is 92
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 8.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Potential fix of wartermelon is weathermen
# Frequency is 0.0
# Match rate is 76
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 23.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is error
# Frequency is 8.0
# Match rate is 80
# ==========================
# Total runtime of 0.3568141460418701 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 7.0
# Match rate is 91
# ==========================
# Potential fix of appel is appel
# Frequency is 0.0
# Match rate is 100
# ==========================
# Potential fix of appel is appell
# Frequency is 0.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is annan
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of bannana is bafana
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is bandanas
# Frequency is 1.0
# Match rate is 80
# ==========================
# Potential fix of bannana is bannon
# Frequency is 0.0
# Match rate is 77
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 9.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lemond
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 20.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is error
# Frequency is 0.0
# Match rate is 80
# ==========================
# Total runtime of 0.41351318359375 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 35.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is pleasures
# Frequency is 0.0
# Match rate is 88
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is banana
# Frequency is 0.0
# Match rate is 92
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is bannon
# Frequency is 0.0
# Match rate is 77
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 8.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is wartime
# Frequency is 0.0
# Match rate is 67
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Potential fix of wartermelon is watermelon
# Frequency is 0.0
# Match rate is 95
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 32.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is error
# Frequency is 6.0
# Match rate is 80
# ==========================
# Total runtime of 0.364591121673584 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 3.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 2.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is banana
# Frequency is 1.0
# Match rate is 92
# ==========================
# Potential fix of bannana is brannan
# Frequency is 0.0
# Match rate is 86
# ==========================
# Potential fix of bannana is bannon
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is bana
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is anynana
# Frequency is 1.0
# Match rate is 86
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 5.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lemond
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of lemone is leon
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of lemone is lemmon
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of lemone is lone
# Frequency is 2.0
# Match rate is 80
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is waterman
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 12.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errors
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is terror
# Frequency is 1.0
# Match rate is 73
# ==========================
# Potential fix of errof is perron
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is error
# Frequency is 1.0
# Match rate is 80
# ==========================
# Total runtime of 0.3650789260864258 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 5.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is pleasures
# Frequency is 0.0
# Match rate is 88
# ==========================
# Potential fix of pleases is pleased
# Frequency is 0.0
# Match rate is 86
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is banana
# Frequency is 0.0
# Match rate is 92
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 12.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Potential fix of wartermelon is waterman
# Frequency is 0.0
# Match rate is 74
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 17.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errors
# Frequency is 3.0
# Match rate is 73
# ==========================
# Potential fix of errof is terror
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is error
# Frequency is 2.0
# Match rate is 80
# ==========================
# Potential fix of errof is perro
# Frequency is 0.0
# Match rate is 80
# ==========================
# Total runtime of 0.35724306106567383 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 5.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is ananda
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is lannan
# Frequency is 0.0
# Match rate is 77
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 7.0
# Match rate is 89
# ==========================
# Potential fix of paer is pajer
# Frequency is 0.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is lemmon
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of lemone is lone
# Frequency is 1.0
# Match rate is 80
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 22.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errors
# Frequency is 3.0
# Match rate is 73
# ==========================
# Potential fix of errof is errol
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of errof is error
# Frequency is 2.0
# Match rate is 80
# ==========================
# Total runtime of 0.37540578842163086 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is wannabe
# Frequency is 1.0
# Match rate is 83
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 7.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is banana
# Frequency is 0.0
# Match rate is 92
# ==========================
# Potential fix of bannana is nana
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is bandana
# Frequency is 1.0
# Match rate is 86
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 8.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is leon
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of lemone is lone
# Frequency is 1.0
# Match rate is 80
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 44.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errors
# Frequency is 2.0
# Match rate is 73
# ==========================
# Potential fix of errof is terror
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is error
# Frequency is 2.0
# Match rate is 80
# ==========================
# Total runtime of 0.3819866180419922 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is hanna
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of wanna is ann
# Frequency is 0.0
# Match rate is 75
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 13.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is qiannan
# Frequency is 0.0
# Match rate is 71
# ==========================
# Potential fix of bannana is nana
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is gannan
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is bandanna
# Frequency is 1.0
# Match rate is 80
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 7.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is wartel
# Frequency is 0.0
# Match rate is 71
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 30.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errors
# Frequency is 4.0
# Match rate is 73
# ==========================
# Potential fix of errof is error
# Frequency is 2.0
# Match rate is 80
# ==========================
# Total runtime of 0.38324975967407227 seconds

# %%
OUT_DIR = './output/2-count-min-sketch+bloom_freq'
if not os.path.exists(OUT_DIR):
    os.makedirs(OUT_DIR)

# %%
for index, words_list in enumerate(words_set_out):
    df_comparisons = pd.DataFrame(data=words_list, index=[format_word(x) for x in correct_sentence.split()])
    df_comparisons = df_comparisons.groupby(df_comparisons.index).first()
    df_comparisons.to_csv(f'{OUT_DIR}/dataset_{index}.csv')

# %%
df_comparisons
# Out:
#                                       matched_words    matched_scores  \
# I                                              None              None
# a                                              None              None
# an                                             None              None
# and                                            None              None
# apple                                        appeal                91
# banana      {gannan, nana, qiannan, anna, bandanna}  {80, 73, 77, 71}
# don't                                          None              None
# error                               {error, errors}          {80, 73}
# have                                           None              None
# hope                                           None              None
# i                                              None              None
# if                                             None              None
# lemon                                         leone                91
# or                                             None              None
# pear                                          paper                89
# please                                       please                92
# possible                                   possible                93
# wanna                            {hanna, ann, anna}      {80, 89, 75}
# watermelon                         {wartel, warren}              {71}
# with                                           None              None
#
#            words_frequency  time_sec
# I                     None   0.38325
# a                     None   0.38325
# an                    None   0.38325
# and                   None   0.38325
# apple                 13.0   0.38325
# banana          {0.0, 1.0}   0.38325
# don't                 None   0.38325
# error           {2.0, 4.0}   0.38325
# have                  None   0.38325
# hope                  None   0.38325
# i                     None   0.38325
# if                    None   0.38325
# lemon                  0.0   0.38325
# or                    None   0.38325
# pear                   7.0   0.38325
# please                 1.0   0.38325
# possible              30.0   0.38325
# wanna                {0.0}   0.38325
# watermelon           {0.0}   0.38325
# with                  None   0.38325
