# %% [markdown]
# <a href="https://colab.research.google.com/github/stavco9/datastreaming-final-project/blob/main/2-Count-Min-Sketch%2BBloom_Freq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install thefuzz
# !pip install mmh3
# Out:
# Collecting thefuzz
#   Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz)
#   Downloading rapidfuzz-3.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 13.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, thefuzz
# Successfully installed rapidfuzz-3.7.0 thefuzz-0.22.1
# Collecting mmh3
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: mmh3
# Successfully installed mmh3-4.1.0

# %%
import bs4
import requests
import json
import sys
import time
import os
import tracemalloc
import pandas as pd
import numpy as np
from random import shuffle
from thefuzz import process, fuzz

# %%
def format_word(word):
  if len(word) > 1:
    last_char = word[-1]
    while not last_char.isalpha():
      word = word[:-1]
      last_char = word[-1]

    first_char = word[0]
    while not first_char.isalpha():
      word = word[1:]
      first_char = word[0]

    word = word.lower()

  return word

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/IDC_MSc/Year1/DataStreamingAlgorithms/DatastreamingFinalProject"
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/IDC_MSc/Year1/DataStreamingAlgorithms/DatastreamingFinalProject

# %%
# !git clone https://github.com/stavco9/datastreaming-final-project.git
# Out:
# fatal: destination path 'datastreaming-final-project' already exists and is not an empty directory.

# %%
sys.path.insert(1, './datastreaming-final-project/modules')
from CountMinSketch.count_min_sketch2 import CountMinSketch2
from BloomFilter.bloom_filter2 import BloomFilter2

# %%
words_set = []
for i in range(10):
  candidates_file = f"./Dataset/dataset_candidates_{i}.txt"
  with open(candidates_file, 'r') as f:
    words_list = []
    for article in list(json.loads(f.read()).values()):
      words_list.extend(article)
    words_set.append({"words_list": words_list})

# %%
NUM_COUNTERS = 300000
NUM_HASH_FUNCTIONS = 100

for index, words_list in enumerate(words_set):
    print(f"Init CMS - {index + 1} of {len(words_set)}")
    cms = CountMinSketch2(buckets=NUM_COUNTERS, tables=NUM_HASH_FUNCTIONS)
    for word in words_list["words_list"]:
        cms.increment(word)
    words_set[index]['words_cms'] = cms
    del cms
# Out:
# Init CMS - 1 of 10
# Init CMS - 2 of 10
# Init CMS - 3 of 10
# Init CMS - 4 of 10
# Init CMS - 5 of 10
# Init CMS - 6 of 10
# Init CMS - 7 of 10
# Init CMS - 8 of 10
# Init CMS - 9 of 10
# Init CMS - 10 of 10

# %%
p = 0.01 #false positive probability

for index, words_list in enumerate(words_set):
    print(f"Init BLOOM - {index + 1} of {len(words_set)}")
    n = len(words_list["words_list"]) #no of items to add
    bloomf = BloomFilter2(n,p)
    for word in words_list["words_list"]:
        bloomf.add(word)
    words_set[index]['words_bloomf'] = bloomf
    del bloomf
# Out:
# Init BLOOM - 1 of 10
# Init BLOOM - 2 of 10
# Init BLOOM - 3 of 10
# Init BLOOM - 4 of 10
# Init BLOOM - 5 of 10
# Init BLOOM - 6 of 10
# Init BLOOM - 7 of 10
# Init BLOOM - 8 of 10
# Init BLOOM - 9 of 10
# Init BLOOM - 10 of 10

# %%
#some_word_with_error = "appel"
some_sentance_with_error = "I wanna appel pleases or a bannana with a paer and a lemone, \
  or a wartermelon if possibe. I hope i don't have an errof in Londaon and in Jerusealm"
correct_sentence = "I wanna apple please or a banana with a pear and a lemon, \
  or a watermelon if possible. I hope i don't have an error in London and in Jerusalem"
diff_words_to_correct = list(set([format_word(x) for x in correct_sentence.split()]) - set([format_word(x) for x in some_sentance_with_error.split()]))
new_sentance = []
words_set_out = []

for index, words_list in enumerate(words_set):
    tracemalloc.start()
    time_start_naive = time.time()
    words_set_out.append({})
    words_set_out[index]["matched_words"] = []
    words_set_out[index]["matched_scores"] = []
    words_set_out[index]["words_frequency"] = []
    start = time.time()
    for word in some_sentance_with_error.split():
        word = format_word(word)
        if not word in words_list["words_bloomf"]:
            success_percentage = max((len(word) - 1) / len(word) * 100, 75)
            print(f"Scanning {word}, success_percentage is {success_percentage}")
            print("==========================")
            word_results = [(format_word(x[0]), x[1]) for x in process.extract(word, words_list["words_list"], scorer=fuzz.ratio)]# if x[1] >= success_percentage]
            word_results = list(set(word_results))
            if (len(word_results) > 0 and word_results[0][1] < 100):
                list_fixes = list([x[0] for x in word_results])
                list_scores = list([x[1] for x in word_results])
                list_freq = list([words_list["words_cms"].count(x[0]) for x in word_results])
                for idx, fix in enumerate(list_fixes):
                    print(f"Potential fix of {word} is {fix}")
                    print(f"Frequency is {list_freq[idx]}")
                    print(f"Match rate is {list_scores[idx]}")
                    print("==========================")
                words_set_out[index]["matched_words"].append(set(list_fixes) if len(list_fixes) > 1 else list_fixes[0])
                words_set_out[index]["matched_scores"].append(set(list_scores) if len(list_scores) > 1 else list_scores[0])
                words_set_out[index]["words_frequency"].append(set(list_freq) if len(list_freq) > 1 else list_freq[0])
            else:
                words_set_out[index]["matched_words"].append(None)
                words_set_out[index]["matched_scores"].append(None)
                words_set_out[index]["words_frequency"].append(None)
                continue
        else:
            print(f"Word {word} is correct. Skipping")
            words_set_out[index]["matched_words"].append(None)
            words_set_out[index]["matched_scores"].append(None)
            words_set_out[index]["words_frequency"].append(None)

    end = time.time()
    words_set_out[index]["total_memory_mb"] = (tracemalloc.get_traced_memory()[0] + sys.getsizeof(words_list["words_list"])) / 1024 / 1024
    tracemalloc.stop()
    print(f"Total runtime of {(end - start)} seconds")
    words_set_out[index]["time_sec"] = (end - start)
# Out:
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 7.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is annandale
# Frequency is 0.0
# Match rate is 75
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is brannan
# Frequency is 0.0
# Match rate is 86
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 25.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is waterman
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 30.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errors
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is error
# Frequency is 1.0
# Match rate is 80
# ==========================
# Potential fix of errof is terror
# Frequency is 5.0
# Match rate is 73
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is jerusalem
# Frequency is 0.0
# Match rate is 89
# ==========================
# Total runtime of 5.61479640007019 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 4.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is santana
# Frequency is 0.0
# Match rate is 71
# ==========================
# Potential fix of bannana is banana
# Frequency is 0.0
# Match rate is 92
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 12.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is leon
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of lemone is lemonade
# Frequency is 0.0
# Match rate is 86
# ==========================
# Potential fix of lemone is lemond
# Frequency is 0.0
# Match rate is 83
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 22.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is herron
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is herro
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of errof is error
# Frequency is 1.0
# Match rate is 80
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is realm
# Frequency is 2.0
# Match rate is 71
# ==========================
# Potential fix of jerusealm is jeremy
# Frequency is 0.0
# Match rate is 67
# ==========================
# Potential fix of jerusealm is jersey
# Frequency is 0.0
# Match rate is 67
# ==========================
# Total runtime of 4.2497453689575195 seconds
# Word I is correct. Skipping
# Word wanna is correct. Skipping
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 15.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is ananda
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is tanana
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is annan
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of bannana is bannau
# Frequency is 0.0
# Match rate is 77
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 8.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 27.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is cerro
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of errof is error
# Frequency is 3.0
# Match rate is 80
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is jerusalem
# Frequency is 0.0
# Match rate is 89
# ==========================
# Total runtime of 5.927282094955444 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 20.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 2.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 9.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lone
# Frequency is 3.0
# Match rate is 80
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is leonie
# Frequency is 0.0
# Match rate is 83
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 38.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errol
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of errof is error
# Frequency is 3.0
# Match rate is 80
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is realm
# Frequency is 5.0
# Match rate is 71
# ==========================
# Potential fix of jerusealm is jerusalem
# Frequency is 0.0
# Match rate is 89
# ==========================
# Total runtime of 4.341012477874756 seconds
# Word I is correct. Skipping
# Word wanna is correct. Skipping
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 4.0
# Match rate is 91
# ==========================
# Word pleases is correct. Skipping
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is annan
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of bannana is banana
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 4.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lone
# Frequency is 1.0
# Match rate is 80
# ==========================
# Potential fix of lemone is lemonier
# Frequency is 0.0
# Match rate is 86
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is leemon
# Frequency is 0.0
# Match rate is 83
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is waterhen
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 11.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is erros
# Frequency is 1.0
# Match rate is 80
# ==========================
# Potential fix of errof is error
# Frequency is 1.0
# Match rate is 80
# ==========================
# Potential fix of errof is terror
# Frequency is 3.0
# Match rate is 73
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is jerusalem
# Frequency is 0.0
# Match rate is 89
# ==========================
# Potential fix of jerusealm is jersey
# Frequency is 0.0
# Match rate is 67
# ==========================
# Total runtime of 3.471261739730835 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is ganna
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 7.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Potential fix of pleases is leases
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is annan
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of bannana is banana
# Frequency is 1.0
# Match rate is 92
# ==========================
# Potential fix of bannana is bannan
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 11.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lerone
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is limone
# Frequency is 0.0
# Match rate is 83
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is waterson
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is arterton
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is weathermen
# Frequency is 0.0
# Match rate is 76
# ==========================
# Potential fix of wartermelon is arteron
# Frequency is 0.0
# Match rate is 78
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 20.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is herro
# Frequency is 0.0
# Match rate is 80
# ==========================
# Potential fix of errof is error
# Frequency is 2.0
# Match rate is 80
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is jerusalem
# Frequency is 0.0
# Match rate is 89
# ==========================
# Total runtime of 6.302277326583862 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 43.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 2.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is bananas
# Frequency is 0.0
# Match rate is 86
# ==========================
# Potential fix of bannana is banana
# Frequency is 0.0
# Match rate is 92
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is annan
# Frequency is 0.0
# Match rate is 83
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 7.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 27.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is errors
# Frequency is 1.0
# Match rate is 73
# ==========================
# Potential fix of errof is error
# Frequency is 3.0
# Match rate is 80
# ==========================
# Potential fix of errof is terror
# Frequency is 15.0
# Match rate is 73
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is jerusalem
# Frequency is 0.0
# Match rate is 89
# ==========================
# Total runtime of 4.534711122512817 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is nwanna
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 21.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 3.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is annandale
# Frequency is 0.0
# Match rate is 75
# ==========================
# Potential fix of bannana is annang
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is annapurna
# Frequency is 0.0
# Match rate is 75
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 4.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lemon
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is lemond
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is afterelton
# Frequency is 0.0
# Match rate is 76
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 10.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is fierro
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of errof is terror
# Frequency is 2.0
# Match rate is 73
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is jerusalem
# Frequency is 0.0
# Match rate is 89
# ==========================
# Total runtime of 3.649113178253174 seconds
# Word I is correct. Skipping
# Scanning wanna, success_percentage is 80.0
# ==========================
# Potential fix of wanna is anna
# Frequency is 0.0
# Match rate is 89
# ==========================
# Scanning appel, success_percentage is 80.0
# ==========================
# Potential fix of appel is appeal
# Frequency is 18.0
# Match rate is 91
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is tanana
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is hannan
# Frequency is 0.0
# Match rate is 77
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 5.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 33.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is error
# Frequency is 3.0
# Match rate is 80
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is jerusalem
# Frequency is 0.0
# Match rate is 89
# ==========================
# Total runtime of 6.296237468719482 seconds
# Word I is correct. Skipping
# Word wanna is correct. Skipping
# Scanning appel, success_percentage is 80.0
# ==========================
# Scanning pleases, success_percentage is 85.71428571428571
# ==========================
# Potential fix of pleases is please
# Frequency is 1.0
# Match rate is 92
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning bannana, success_percentage is 85.71428571428571
# ==========================
# Potential fix of bannana is annandale
# Frequency is 0.0
# Match rate is 75
# ==========================
# Potential fix of bannana is annan
# Frequency is 0.0
# Match rate is 83
# ==========================
# Potential fix of bannana is banana
# Frequency is 0.0
# Match rate is 92
# ==========================
# Potential fix of bannana is anna
# Frequency is 0.0
# Match rate is 73
# ==========================
# Potential fix of bannana is bandanna
# Frequency is 1.0
# Match rate is 80
# ==========================
# Word with is correct. Skipping
# Word a is correct. Skipping
# Scanning paer, success_percentage is 75.0
# ==========================
# Potential fix of paer is paper
# Frequency is 6.0
# Match rate is 89
# ==========================
# Word and is correct. Skipping
# Word a is correct. Skipping
# Scanning lemone, success_percentage is 83.33333333333334
# ==========================
# Potential fix of lemone is lemonade
# Frequency is 0.0
# Match rate is 86
# ==========================
# Potential fix of lemone is leone
# Frequency is 0.0
# Match rate is 91
# ==========================
# Potential fix of lemone is lemore
# Frequency is 0.0
# Match rate is 83
# ==========================
# Word or is correct. Skipping
# Word a is correct. Skipping
# Scanning wartermelon, success_percentage is 90.9090909090909
# ==========================
# Potential fix of wartermelon is waterloo
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is waterhen
# Frequency is 0.0
# Match rate is 74
# ==========================
# Potential fix of wartermelon is warren
# Frequency is 0.0
# Match rate is 71
# ==========================
# Word if is correct. Skipping
# Scanning possibe, success_percentage is 85.71428571428571
# ==========================
# Potential fix of possibe is possible
# Frequency is 17.0
# Match rate is 93
# ==========================
# Word I is correct. Skipping
# Word hope is correct. Skipping
# Word i is correct. Skipping
# Word don't is correct. Skipping
# Word have is correct. Skipping
# Word an is correct. Skipping
# Scanning errof, success_percentage is 80.0
# ==========================
# Potential fix of errof is error
# Frequency is 5.0
# Match rate is 80
# ==========================
# Word in is correct. Skipping
# Scanning londaon, success_percentage is 85.71428571428571
# ==========================
# Potential fix of londaon is london
# Frequency is 0.0
# Match rate is 92
# ==========================
# Word and is correct. Skipping
# Word in is correct. Skipping
# Scanning jerusealm, success_percentage is 88.88888888888889
# ==========================
# Potential fix of jerusealm is realm
# Frequency is 1.0
# Match rate is 71
# ==========================
# Potential fix of jerusealm is jeremy
# Frequency is 0.0
# Match rate is 67
# ==========================
# Total runtime of 4.416606426239014 seconds

# %%
OUT_DIR = './output/2-count-min-sketch+bloom_freq'
if not os.path.exists(OUT_DIR):
    os.makedirs(OUT_DIR)

# %%
for index, words_list in enumerate(words_set_out):
    df_comparisons = pd.DataFrame(data=words_list, index=[format_word(x) for x in correct_sentence.split()])
    df_comparisons = df_comparisons.groupby(df_comparisons.index).first()
    df_comparisons.to_csv(f'{OUT_DIR}/dataset_{index}.csv')

# %%
df_comparisons
# Out:
#                                          matched_words        matched_scores  \
# I                                                 None                  None
# a                                                 None                  None
# an                                                None                  None
# and                                               None                  None
# apple                                             None                  None
# banana      {banana, annan, anna, annandale, bandanna}  {73, 75, 80, 83, 92}
# don't                                             None                  None
# error                                            error                    80
# have                                              None                  None
# hope                                              None                  None
# i                                                 None                  None
# if                                                None                  None
# in                                                None                  None
# jerusalem                              {realm, jeremy}              {67, 71}
# lemon                        {lemonade, leone, lemore}          {83, 91, 86}
# london                                          london                    92
# or                                                None                  None
# pear                                             paper                    89
# please                                          please                    92
# possible                                      possible                    93
# wanna                                             None                  None
# watermelon                {waterloo, warren, waterhen}              {74, 71}
# with                                              None                  None
#
#            words_frequency  total_memory_mb  time_sec
# I                     None         3.798833  4.416606
# a                     None         3.798833  4.416606
# an                    None         3.798833  4.416606
# and                   None         3.798833  4.416606
# apple                 None         3.798833  4.416606
# banana          {0.0, 1.0}         3.798833  4.416606
# don't                 None         3.798833  4.416606
# error                  5.0         3.798833  4.416606
# have                  None         3.798833  4.416606
# hope                  None         3.798833  4.416606
# i                     None         3.798833  4.416606
# if                    None         3.798833  4.416606
# in                    None         3.798833  4.416606
# jerusalem       {0.0, 1.0}         3.798833  4.416606
# lemon                {0.0}         3.798833  4.416606
# london                 0.0         3.798833  4.416606
# or                    None         3.798833  4.416606
# pear                   6.0         3.798833  4.416606
# please                 1.0         3.798833  4.416606
# possible              17.0         3.798833  4.416606
# wanna                 None         3.798833  4.416606
# watermelon           {0.0}         3.798833  4.416606
# with                  None         3.798833  4.416606
